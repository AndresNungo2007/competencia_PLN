# %% [markdown]
# # Versión Light.
# **Versión**: 06
#
# - Notebook que sirve para realizar pruebas con poquitos ejemplos. Tomado de la carpeta smalltrain, por si desea hacer pruebas de su lado.
# - Como se puede observar, esta ruta `data/smalltrain/natural_purchase_order_6.json` tiene solo 222 ejemplos en total.

# %% [markdown]
# # Librerías

# %%
import os
import json
import re
import math
import random
from typing import Any, Dict, List, Optional
import csv

import torch
from torch.utils.data import DataLoader, Dataset as TorchDataset
from torch.optim import AdamW
import torch.nn.functional as F
from torch.nn.utils.rnn import pad_sequence
import torch.utils.checkpoint
from tqdm.auto import tqdm

import matplotlib.pyplot as plt
import numpy as np
import evaluation_metric as custom_metrics #el archivo .py con las métricas personalizadas, proveida por el curso

#import warnings
from importlib.metadata import version

from datasets import Dataset
from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    BitsAndBytesConfig,
    get_scheduler
)
from peft import LoraConfig, get_peft_model, prepare_model_for_kbit_training
from transformers import logging as hf_logging
hf_logging.set_verbosity_warning()

# %%
# Ignorar las warnings
#warnings.filterwarnings("ignore")  → dejar esto al final para la entrega, dado que se debe revisar que se debe mejorar en el código

# Versiones utilizadas
librerias = [
    "numpy",
    "matplotlib",
    "torch",
    "tqdm",
    "datasets",
    "transformers",
    "peft",
    "importlib-metadata"
]
for library in librerias:
    print(library, ": ", version(library))

# !python --version
# Out:
# numpy :  1.26.4
# matplotlib :  3.10.5
# torch :  2.8.0+cu128
# tqdm :  4.67.1
# datasets :  4.0.0
# transformers :  4.56.0
# peft :  0.18.0
# importlib-metadata :  8.7.0
# Python 3.12.12

# %% [markdown]
# # Variables globales y funciones auxiliares

# %% [markdown]
# ### Valores por defecto

# %%
# Directorios
DATA_PATH = "data/smalltrain/natural_purchase_order_6.json" # por ahora tomo este ejemplo light de 222 registros
OUTPUT_DIR = "output/vlgl_06"
EXPECTED_JSON_FILE = "data/template/expected_output.json"
EXPECTED_JSON = None
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Modelo
MODEL_NAME = "Qwen/Qwen3-0.6B-Base"

# Configuración del dispositivo + semillas
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {DEVICE}")
GLB_SEED = 42
torch.manual_seed(GLB_SEED)
random.seed(GLB_SEED)
np.random.seed(GLB_SEED)
if DEVICE == "cuda":
    torch.cuda.manual_seed_all(GLB_SEED)
# Out:
# Using device: cuda

# %% [markdown]
# ### Valores globales de prueba

# %%
# Data / tokenization
TEST_SIZE = 0.2
MAX_LENGTH = 2048 #menor de este valor la tokenización está truncando el JSON objetivo con 1024 funciona bien

# Dataloader
BATCH_SIZE = 1
#NUM_WORKERS = 2

# Entrenamiento
GRAD_ACCUM_STEPS = 4
EPOCHS = 4
WARMUP_RATIO = 0.05 # 5% de los steps totales, sugerencia otra 0.03
#WARMUP_STEPS = 10 # con 10 va bien # revisar este 100, mejor usar WARMUP_RATIO

# AdamW
LEARNING_RATE = 2e-4 # con 2e-4 es agresivo pero funciona bien, riesgo de overfitting
WEIGHT_DECAY = 0.01
BETAS = (0.9, 0.999)
EPS = 1e-8
SCHEDULER_TYPE = "linear" # linear, cosine, cosine_with_restarts, polynomial, constant, constant_with_warmup  #cosine no va bien
CLIP_NORM = 1.0

# LoRA
LORA_R = 16
LORA_ALPHA = 32
LORA_DROPOUT = 0.05
TARGET_MODULES = ["q_proj", "k_proj", "v_proj", "o_proj"]

# Evaluación
NUM_VAL_EXAMPLES = 45
GEN_MAX_NEW_TOKENS = 512
BEAM_CANDIDATES = 4

# %% [markdown]
# # Carga de archivos y datos

# %% [markdown]
# Cargar archivo ejemplo JSON esperado para predicción, aunque no se usa todavía, es para mejorar un poco la prediccion...

# %%
with open(EXPECTED_JSON_FILE, "r", encoding="utf-8") as f:
    EXPECTED_JSON = json.load(f)

# %% [markdown]
# **Cargar dataset**
# Esto es temporal mientras se ajusta el F1-Score para aquellos que estan dando cero. Temporal en cargar solo un archivo, dado que se deben cargar todos los JSON para entrenar.

# %%
with open(DATA_PATH, "r", encoding="utf-8") as f:
    raw_data = json.load(f)


# Obtener longitudes de texto para ajustar MAX_LENGTH - histograma
longitudes = [len(item["natural_language"]) for item in raw_data]
plt.figure(figsize=(8, 4))
plt.hist(longitudes, bins=20)  # puedes ajustar el número de bins
plt.title("Distribución de longitudes de 'natural_language'")
plt.xlabel("Longitud del texto")
plt.ylabel("Cantidad de ejemplos")
plt.grid(True)
plt.show()

# %%
# convert to Hugging Face Dataset
hf_dataset = Dataset.from_list(raw_data)

# split train / validation
split = hf_dataset.train_test_split(test_size=TEST_SIZE, seed=GLB_SEED)
train_list = split['train']
val_list = split['test']

print(f"Train examples: {len(train_list)}, Val examples: {len(val_list)}")
# Out:
# Train examples: 177, Val examples: 45

# %%
print("Cargando tokenizer y modelo (esto puede tardar)...")

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME, trust_remote_code=True) # dejar trust_remote_code=True para Qwen
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    quantization_config=bnb_config,
    device_map="auto",
    trust_remote_code=True,
    dtype=torch.bfloat16
)

# preparar para k-bit training
model = prepare_model_for_kbit_training(model)

# Desactivar cache y habilitar checkpointing seguro
model.config.use_cache = False
try:
    model.gradient_checkpointing_enable(gradient_checkpointing_kwargs={"use_reentrant": False})
except TypeError:
    # fallback if the signature is different
    model.gradient_checkpointing_enable()
torch.utils.checkpoint.use_reentrant = False

# Configurar LoRA
lora_config = LoraConfig(
    r=LORA_R,
    lora_alpha=LORA_ALPHA,
    lora_dropout=LORA_DROPOUT,
    target_modules=TARGET_MODULES,
    bias="none",
    task_type="CAUSAL_LM"
)

model = get_peft_model(model, lora_config)
model.print_trainable_parameters()
# Out:
# Cargando tokenizer y modelo (esto puede tardar)...
# trainable params: 4,587,520 || all params: 600,637,440 || trainable%: 0.7638

# %% [markdown]
# ## Construcción del prompt para que genere el JSON

# %%
# Construcción de prompt
def build_prompt(natural_text: str) -> str:
    instructions = (
        "Eres un extractor de órdenes de compra. Genera SOLO un JSON válido EXACTAMENTE con los campos requeridos.\n"
        "Reglas:\n"
        "- Usa null cuando un campo no exista.\n"
        "- \"buyer\" debe existir; si name/email/contact/addresses faltan, déjalos en null.\n"
        "- Si addresses está vacío o no existe -> \"addresses\": null.\n"
        "- Si purchases está vacío o no existe -> \"purchases\": null.\n"
        "- shipping es opcional; si falta -> \"shipping\": null.\n"
        "- Asegura que los tipos de datos principales sean correctos (quantity: entero; country uno de US/CA/GB/ES/CO/DE/FR).\n\n"
    )
    prompt = instructions + "Texto:\n" + natural_text + "\n\nRESPONDE SOLO CON EL JSON VÁLIDO (nada más):\nJSON:\n"
    return prompt

# Construcción del ejemplo de entrenamiento (prompt + target JSON)
def build_training_example(example: Dict[str, Any]) -> str:
    natural = example['natural_language']
    target_json = json.dumps(example['json_data'], ensure_ascii=False) # TODO: revisar indent=2
    prompt = build_prompt(natural)
    return prompt + target_json


# Tokenización (precompuesta) y construcción de datasets de tensores
def tokenize_example_textpair(textpair: str):
    enc = tokenizer(textpair, truncation=True, max_length=MAX_LENGTH, padding='max_length', return_tensors='pt') # todo: padding=False para probar, add_special_tokens=True
    labels = enc['input_ids'].clone()
    labels[labels == tokenizer.pad_token_id] = -100
    return {'input_ids': enc['input_ids'].squeeze(0), 'attention_mask': enc['attention_mask'].squeeze(0), 'labels': labels.squeeze(0)}

train_tokens = [tokenize_example_textpair(build_training_example(x)) for x in train_list]
val_tokens = [tokenize_example_textpair(build_training_example(x)) for x in val_list]

# Simple Dataset + collate_fn (dinámico)
class SimpleTorchDataset(TorchDataset):
    def __init__(self, tokens_list):
        self.data = tokens_list
    def __len__(self):
        return len(self.data)
    def __getitem__(self, idx):
        return {k: v for k, v in self.data[idx].items()}
    
train_dataset = SimpleTorchDataset(train_tokens)
val_dataset = SimpleTorchDataset(val_tokens)

def collate_fn(batch):
    return {
        'input_ids': torch.stack([b['input_ids'] for b in batch]),
        'attention_mask': torch.stack([b['attention_mask'] for b in batch]),
        'labels': torch.stack([b['labels'] for b in batch])
    }

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, collate_fn=collate_fn)
val_loader = DataLoader(val_dataset, batch_size=1, shuffle=False, collate_fn=collate_fn)

# %% [markdown]
# ## Variación de parámetros para optimizador

# %% [markdown]
#  Optimizer (intenta Adam8bit de bitsandbytes, si no fallback a AdamW de torch).
#
#  Notas:
#  Adam8bit + get_scheduler cosine: no funciono bien, F1 siempre da cero, mejor AdamW

# %%
# Optimizer + Scheduler
total_steps_per_epoch  = math.ceil(len(train_loader) / GRAD_ACCUM_STEPS)
total_training_steps = EPOCHS * total_steps_per_epoch
num_warmup_steps = int(total_training_steps * WARMUP_RATIO) # warmup calculado desde warmup_ratio

print(f"Total training steps: {total_training_steps}, Warmup steps: {num_warmup_steps}")

# Optimizador
trainable_params = [p for p in model.parameters() if p.requires_grad]
optimizer = AdamW(trainable_params, lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY, betas=BETAS, eps=EPS)

# SCHEDULER CON WARMUP
scheduler = get_scheduler(name=SCHEDULER_TYPE, 
                          optimizer=optimizer, 
                          num_warmup_steps=num_warmup_steps, 
                          num_training_steps=total_training_steps)
# Out:
# Total training steps: 180, Warmup steps: 9

# %%
#raise Exception("STOP - revisar código antes de continuar")

# %%
# Entrenamiento manual con AMP (torch.amp) y tqdm
scaler = torch.amp.GradScaler(device='cuda') if DEVICE.startswith('cuda') else torch.amp.GradScaler()
model.to(DEVICE)
model.train()

global_step = 0
optimizer.zero_grad()
for epoch in range(EPOCHS):
    running_loss = 0.0
    pbar = tqdm(enumerate(train_loader), total=len(train_loader), desc=f"Epoch {epoch+1}/{EPOCHS}")
    optimizer.zero_grad()
    for step, batch in pbar:
        input_ids = batch['input_ids'].to(DEVICE)
        attention_mask = batch['attention_mask'].to(DEVICE)
        labels = batch['labels'].to(DEVICE)

        with torch.amp.autocast(device_type='cuda' if DEVICE.startswith('cuda') else 'cpu'):
            outputs = model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)
            loss = outputs.loss / GRAD_ACCUM_STEPS

        scaler.scale(loss).backward()
        running_loss += loss.item() * GRAD_ACCUM_STEPS

        # UPDATE BLOCK: only when accumulation completes
        if (step + 1) % GRAD_ACCUM_STEPS == 0 or (step + 1) == len(train_loader):
            scaler.unscale_(optimizer)  # 1) Unscale gradients (necessary for clipping)
            torch.nn.utils.clip_grad_norm_(model.parameters(), CLIP_NORM) # 2) Clip gradients
            scaler.step(optimizer) # 3) Optimizer step (scaled)
            scheduler.step() # 4) Scheduler step → usa warmup aquí
            optimizer.zero_grad() # 5) Clear gradients
            scaler.update()  # 6) Scaler update
            global_step += 1

            avg_loss = running_loss / (step + 1)
            pbar.set_postfix({'loss': f"{avg_loss:.4f}", 'lr': scheduler.get_last_lr()[0]})
            #pbar.set_postfix({ "loss": f"{running_loss / (step+1):.4f}", "lr": scheduler.get_last_lr()[0]})

    print(f"Epoch {epoch+1} finished — avg loss: {running_loss / len(train_loader):.4f}")
# Out:
# Epoch 1/4:   0%|          | 0/177 [00:00<?, ?it/s]
# Epoch 1 finished — avg loss: 1.7930
# Epoch 2/4:   0%|          | 0/177 [00:00<?, ?it/s]
# Epoch 2 finished — avg loss: 1.3568
# Epoch 3/4:   0%|          | 0/177 [00:00<?, ?it/s]
# Epoch 3 finished — avg loss: 1.2611
# Epoch 4/4:   0%|          | 0/177 [00:00<?, ?it/s]
# Epoch 4 finished — avg loss: 1.2074

# %%
# Entrenando modelo se demora: 9min 2.3 segundos con 177 ejemplos en entrenamiento

# %%
# Guardar modelo para validar en datos test. 👈 aqui ver como se saca el "weights.pt"
OUTPUT_DIR_MODEL = os.path.join(OUTPUT_DIR, "modfinal")
os.makedirs(OUTPUT_DIR_MODEL, exist_ok=True)

model.save_pretrained(OUTPUT_DIR_MODEL)
tokenizer.save_pretrained(OUTPUT_DIR_MODEL)

print('Modelo para restaurar guardado en', OUTPUT_DIR_MODEL)
# Out:
# ('output/vlgl_06\\modfinal\\tokenizer_config.json',
#  'output/vlgl_06\\modfinal\\special_tokens_map.json',
#  'output/vlgl_06\\modfinal\\chat_template.jinja',
#  'output/vlgl_06\\modfinal\\vocab.json',
#  'output/vlgl_06\\modfinal\\merges.txt',
#  'output/vlgl_06\\modfinal\\added_tokens.json',
#  'output/vlgl_06\\modfinal\\tokenizer.json')

# %% [markdown]
# ## Validación del modelo entrenado en los datos test

# %%
# Generación robusta y normalización POST-PREDICCIÓN

# Generar texto bruto desde el modelo - EN MODO EVALUACIÓN
def generate_json_raw(text: str, max_new_tokens: int = 256) -> str:
    prompt = build_prompt(text)
    enc = tokenizer(prompt, return_tensors='pt', truncation=True, padding=True, max_length=MAX_LENGTH).to(DEVICE)
    input_ids = enc['input_ids']
    attention_mask = enc['attention_mask']
    pad_id = tokenizer.pad_token_id or tokenizer.eos_token_id

    model.eval()
    with torch.no_grad():
        out = model.generate(
            input_ids=input_ids,
            attention_mask=attention_mask,
            max_new_tokens=max_new_tokens,
            do_sample=False,
            pad_token_id=pad_id,
            eos_token_id=tokenizer.eos_token_id,
            use_cache=False
        )
    decoded = tokenizer.decode(out[0], skip_special_tokens=True)

    # Heurística: recortar hasta la última '}' para obtener JSON válido en la mayoría de casos
    if "{" in decoded and "}" in decoded:
        last_brace = decoded.rfind("}")
        decoded = decoded[: last_brace + 1]
    return decoded

def extract_json_from_text(text: str) -> Any:
    # Buscar primer bloque JSON {...}
    matches = re.findall(r"\{[\s\S]*\}", text)
    if matches:
        for m in matches:
            candidate = m.replace("'", '"')
            try:
                return json.loads(candidate)
            except Exception:
                continue
    # fallback: si hay 'JSON:' tomar lo que sigue
    if "JSON:" in text:
        part = text.split("JSON:")[-1].strip()
        part = part.strip("`\n ")
        try:
            return json.loads(part)
        except Exception:
            try:
                return json.loads(part.replace("'", '"'))
            except Exception:
                return None
    return None

# %%
# NUM_VAL_EXAMPLES = 45 # si se desea hacer subset, de lo contrario dejar todo
# usar NUM_VAL_EXAMPLES: `for idx, ex in enumerate(tqdm(val_list.select(range(min(NUM_VAL_EXAMPLES, len(val_list)))), desc="Eval")):`

results = []
for idx, ex in enumerate(tqdm(val_list, desc="Evaluación en TEST")):
    text = ex["natural_language"]
    raw = generate_json_raw(text, max_new_tokens=GEN_MAX_NEW_TOKENS) # aplica evaluacion del modelo
    pred_obj = extract_json_from_text(raw)
    true_json = ex["json_data"]

    if pred_obj is None:
        f1 = 0.0
    else:
        try:
            f1 = custom_metrics.evaluate_json(true_json, json.dumps(pred_obj, ensure_ascii=False))
        except Exception:
            f1 = float(1.0 if pred_obj == true_json else 0.0)

    results.append({"idx": idx, "f1": f1, "raw": raw, "pred": pred_obj, "true": true_json})
# Out:
# Evaluación en TEST:   0%|          | 0/45 [00:00<?, ?it/s]

# %%
# Validacion de 45 ejemplos en datos de test: 16min 52.3seg

# %%
 # Resumen de resultados en test: ver histrograma de F1 scores
f1_scores = [r['f1'] for r in results]
plt.figure(figsize=(8, 4))
plt.plot(range(1, len(f1_scores) + 1), f1_scores, marker='o')
plt.title("F1 Scores por ejemplo de validación")
plt.xlabel("Total ejemplos de validación")
plt.ylabel("F1 Score")
plt.grid(True)
plt.show()

# %%
results[1] # observar que hay
# Out:
# {'idx': 1,
#  'f1': 0.8911290322580645,
#  'raw': 'Eres un extractor de órdenes de compra. Genera SOLO un JSON válido EXACTAMENTE con los campos requeridos.\nReglas:\n- Usa null cuando un campo no exista.\n- "buyer" debe existir; si name/email/contact/addresses faltan, déjalos en null.\n- Si addresses está vacío o no existe -> "addresses": null.\n- Si purchases está vacío o no existe -> "purchases": null.\n- shipping es opcional; si falta -> "shipping": null.\n- Asegura que los tipos de datos principales sean correctos (quantity: entero; country uno de US/CA/GB/ES/CO/DE/FR).\n\nTexto:\nAsunto: Pedido de Pasabocas\n\nHola, buen día 😊,\n\nEspero que estés bien. Quería hacer un nuevo pedido, tal como hicimos la vez pasada. Me gustaría solicitar un par de esos deliciosos pasabocas JBO mixto BBQ, creo que serían unas dos unidades —más o menos, si no me olvido de la última vez que pedimos. Si no me equivoco, esa fue la cantidad que pedí antes, así que espero que esta vez no haya problema con eso.\n\nAdemás, sería genial si pudieras aplicarle el descuento que usé anteriormente, ¿cómo se llamaba? Ah, sí, "vaCz-pypT". Confío en que aún está disponible. \n\nPor cierto, la dirección de envío es un poco complicada, así que aquí te dejo una de ellas; es en Ruppersbergerring, un número noventa, en Gerolzhofen, que está en Alemania y el código postal es 43127. Pero también tengo otra dirección en Estados Unidos, que es 841 Leslie Walks Apt. 015, New Stephanieland… ese es en Connecticut, código postal 05744. Si por alguna razón no puedes enviar a la primera dirección, avísame. Ah, y hay otra dirección en Francia que también podría interesar: 737, avenue de Dijoux en Rocher, con código postal 11576, solo si todo falla. 😅\n\nMe gustó mucho el servicio la última vez, y me gustaría que el método de envío fuera algo como "entrega estándar" o "normal", creo que eso sería lo mejor sin apuros. Por favor, no envíes el paquete este fin de semana, tengo algunos planes y no quiero alarmar a mi familia con una entrega sorpresiva. \n\nAprecio mucho tu atención y espero que podamos concretar esto pronto. Por favor, confirma cuando puedas.\n\n¡Gracias de antemano!\n\nSaludos,\nJulia Lee\njulia_lee@hotmail.com\n\nRESPONDE SOLO CON EL JSON VÁLIDO (nada más):\nJSON:\n{"buyer": {"addresses": [{"city": "Ruppersbergerring", "country": "DE", "postal_code": "43127", "state": null, "street": "Ruppersbergerring 99"}, {"city": "New Stephanieland", "country": "US", "postal_code": "05744", "state": "CT", "street": "841 Leslie Walks Apt. 015"}, {"city": "Rocher", "country": "FR", "postal_code": "11576", "state": null, "street": "737, avenue de Dijoux"}], "contact": null, "email": "julia_lee@hotmail.com", "name": "Julia Lee"}, "purchases": [{"currency": "GBP", "discount_code": "vaCz-pypT", "product_name": "Pasabocas JBO mixto BBQ ", "quantity": 2}], "shipping": {"method": "standard", "preferred_by": null}}',
#  'pred': {'buyer': {'addresses': [{'city': 'Ruppersbergerring',
#      'country': 'DE',
#      'postal_code': '43127',
#      'state': None,
#      'street': 'Ruppersbergerring 99'},
#     {'city': 'New Stephanieland',
#      'country': 'US',
#      'postal_code': '05744',
#      'state': 'CT',
#      'street': '841 Leslie Walks Apt. 015'},
#     {'city': 'Rocher',
#      'country': 'FR',
#      'postal_code': '11576',
#      'state': None,
#      'street': '737, avenue de Dijoux'}],
#    'contact': None,
#    'email': 'julia_lee@hotmail.com',
#    'name': 'Julia Lee'},
#   'purchases': [{'currency': 'GBP',
#     'discount_code': 'vaCz-pypT',
#     'product_name': 'Pasabocas JBO mixto BBQ ',
#     'quantity': 2}],
#   'shipping': {'method': 'standard', 'preferred_by': None}},
#  'true': {'buyer': {'addresses': [{'city': 'Gerolzhofen',
#      'country': 'DE',
#      'postal_code': '43127',
#      'state': None,
#      'street': 'Ruppersbergerring 90'},
#     {'city': 'New Stephanieland',
#      'country': 'US',
#      'postal_code': '05744',
#      'state': 'CT',
#      'street': '841 Leslie Walks Apt. 015'},
#     {'city': 'Rocher',
#      'country': 'FR',
#      'postal_code': '11576',
#      'state': None,
#      'street': '737, avenue de Dijoux'}],
#    'contact': None,
#    'email': 'julia_lee@hotmail.com',
#    'name': 'Julia Lee'},
#   'purchases': [{'currency': None,
#     'discount_code': 'vaCz-pypT',
#     'product_name': 'Pasabocas JBO mixto BBQ ',
#     'quantity': 2}],
#   'shipping': {'method': 'standard', 'preferred_by': None}}}

# %%
# Guardar CSV - resultados de validación
OUTPUT_DIR_VAL = os.path.join(OUTPUT_DIR, "result_validation")
os.makedirs(OUTPUT_DIR_VAL, exist_ok=True)
csv_path = os.path.join(OUTPUT_DIR_VAL, 'validation_results.csv')
with open(csv_path, 'w', encoding='utf-8', newline='') as f:
    writer = csv.DictWriter(f, fieldnames=['idx','f1','raw','pred','true'])
    writer.writeheader()
    for r in results:
        writer.writerow({
            'idx': r['idx'],
            'f1': r['f1'],
            'raw': r['raw'],
            'pred': json.dumps(r['pred'], ensure_ascii=False),
            'true': json.dumps(r['true'], ensure_ascii=False)
        })
print('CSV guardado en', csv_path)
# Out:
# CSV guardado en output/vlgl_06\result_validation\validation_results.csv

# %%
# Histograma F1
f1_scores = [r['f1'] for r in results]
plt.figure()
plt.hist(f1_scores, bins=10)
plt.title('Distribución de F1')
plt.xlabel('F1')
plt.ylabel('Frecuencia')
plt.savefig(os.path.join(OUTPUT_DIR, 'f1_distribution.png'))
plt.show()
plt.close()
print('Histograma guardado en', os.path.join(OUTPUT_DIR, 'f1_distribution.png'))
# Out:
# Histograma guardado en output/vlgl_06\f1_distribution.png

# %%
# Mostrar peores 3 ejemplos
sorted_by_f1 = sorted(results, key=lambda x: x['f1'])
print('\nPeores 3 ejemplos:')
for r in sorted_by_f1[:3]:
    print(f"Ejemplo #{r['idx']} - F1 Score: {r['f1']}")
    print("-"*90)
    print('Texto:', r['raw'])
    print("-"*90)
    print('Pred_normalizado:', r['pred'])
    print("-"*90)
    print('True:', r['true'])
    print('='*150)
# Out:
# Peores 3 ejemplos:
# Ejemplo #8 - F1 Score: 0.0
# ------------------------------------------------------------------------------------------
# Texto: Eres un extractor de órdenes de compra. Genera SOLO un JSON válido EXACTAMENTE con los campos requeridos.
# Reglas:
# - Usa null cuando un campo no exista.
# - "buyer" debe existir; si name/email/contact/addresses faltan, déjalos en null.
# - Si addresses está vacío o no existe -> "addresses": null.
# - Si purchases está vacío o no existe -> "purchases": null.
# - shipping es opcional; si falta -> "shipping": null.
# - Asegura que los tipos de datos principales sean correctos (quantity: entero; country uno de US/CA/GB/ES/CO/DE/FR).
#
# Texto:
# ¡Hey! 👋 Espero que estés genial.
#
# Te escribo porque necesito hacer un pedido de unas botellas de vino blanco, específicamente de esa reserva de chardonnay de Balduzzi que me encanta 🍷. Me vendrían bien 8 de esas, como las que pedí la vez pasada.
#
# Ah, por cierto, tengo varias direcciones, pero creo que lo mejor sería enviarlas a mi casita en Lopezhaven, a la dirección que tengo en 6031 Michael Run, Apt. 206, código postal G5G3B5, en Canadá. Aunque también tengo otra en West Timothy, WV, y otra en Coreyberg, ND, así que avísame si necesitas más detalles sobre eso. 🤷‍♂️
#
# Cuéntame si puedes hacer el envío lo antes posible, aunque sin apuros este fin de semana; a veces me gusta hacer una buena degustación y no quiero que llegue justo cuando tengo otras cosas. ¡Ayer llovió un montón, así que me vendría bien un buen vino para acompañar la tarde! 😊
#
# Por último, si hay algún descuento o algo así, no estaría mal saberlo. Espero tu respuesta pronto. ¡Gracias! 🍾
#
# RESPONDE SOLO CON EL JSON VÁLIDO (nada más):
# JSON:
# {"buyer": {"addresses": [{"city": "Lopezhaven", "country": "CA", "postal_code": "G5G3B5", "state": null, "street": "6031 Michael Run Apt. 206"}
# ------------------------------------------------------------------------------------------
# Pred_normalizado: None
# ------------------------------------------------------------------------------------------
# True: {'buyer': {'addresses': [{'city': 'Lopezhaven', 'country': 'CA', 'postal_code': 'G5G3B5', 'state': None, 'street': '6031 Michael Run Apt. 206'}, {'city': 'West Timothy', 'country': 'US', 'postal_code': '34435', 'state': 'WV', 'street': '17492 David Bypass'}, {'city': 'Coreyberg', 'country': 'US', 'postal_code': '92355', 'state': 'ND', 'street': '6901 Marie Square Apt. 551'}], 'contact': None, 'email': None, 'name': 'Frank Cook'}, 'purchases': [{'currency': None, 'discount_code': None, 'product_name': 'Vino blanco balduzzi reserva chardonnay ', 'quantity': 8}], 'shipping': None}
# ======================================================================================================================================================
# Ejemplo #25 - F1 Score: 0.0
# ------------------------------------------------------------------------------------------
# Texto: Eres un extractor de órdenes de compra. Genera SOLO un JSON válido EXACTAMENTE con los campos requeridos.
# Reglas:
# - Usa null cuando un campo no exista.
# - "buyer" debe existir; si name/email/contact/addresses faltan, déjalos en null.
# - Si addresses está vacío o no existe -> "addresses": null.
# - Si purchases está vacío o no existe -> "purchases": null.
# - shipping es opcional; si falta -> "shipping": null.
# - Asegura que los tipos de datos principales sean correctos (quantity: entero; country uno de US/CA/GB/ES/CO/DE/FR).
#
# Texto:
# Asunto: Solicitud de Pedido
#
# Hola,
#
# Espero que estés muy bien. Soy Kevin, y me gustaría hacer un pedido similar al de la vez pasada. Estuve pensando en esos deliciosos productos que ustedes tienen, y me preguntaba si podrías ayudarme con lo siguiente.
#
# Me gustaría pedir alrededor de cuatro unidades de un producto que creo que era Casero Vainilla de Bimbo, algo así como cuatro… si no me equivoco. En cuanto al precio, no estoy seguro si es por ahí de las libras (GBP), así que un par de detalles sobre eso tampoco estarían mal.
#
# Por otro lado, estaba pensando en que el método de envío podría ser una recogida, ya que mañana debería ser un mal día para entregar – hay un clima extraño que me preocupa. Así que me gustaría que estuviera listo para el 21 de enero por la tarde si es posible, como a eso de las seis y media o algo así. No obstante, no quiero apresurarles, así que si no es posible para ese día, simplemente háganmelo saber.
#
# Por cierto, no sé si tenía mencionarte esto, pero mi número es el 381-460-3626, extensión 49073. Aunque, en realidad, si puedes contactarme a través de mi correo, kevin_singleton@hotmail.com, sería preferible. También me puedes escribir a carlos24@example.org, que es un correo alternativo en caso de que no logres contactarme.
#
# Ah, casi lo olvido, si pudieras confirmarme que la dirección correcta para la recogida es Cr. 134 Bis # 6-6, en Agua de Dios, sería genial. A veces, me confundo un poco, ya que tengo otras direcciones en mente, como una en Port Shaun, Oklahoma, y otra en Yangbury, pero esta última no la usaré para este pedido.
#
# Gracias de antemano por tu ayuda. Recuerda, me encantaría tener mi pedido pronto, pero no este fin de semana, si es que no es mucha molestia.
#
# Saludos,
# Kevin 😊
#
# RESPONDE SOLO CON EL JSON VÁLIDO (nada más):
# JSON:
# {"buyer": {"addresses": [{"city": "Agua de Dios", "country": "CO", "postal_code": "45100", "state": null, "street": "Cr. 134 Bis # 6-6"}
# ------------------------------------------------------------------------------------------
# Pred_normalizado: None
# ------------------------------------------------------------------------------------------
# True: {'buyer': {'addresses': [{'city': 'Agua de Dios', 'country': 'CO', 'postal_code': '191892', 'state': None, 'street': 'Cr. 134 Bis # 6-6'}, {'city': 'Port Shaun', 'country': 'US', 'postal_code': '72597', 'state': 'OK', 'street': '277 Spears Greens Apt. 839'}, {'city': 'Yangbury', 'country': 'CA', 'postal_code': 'M5X4V5', 'state': None, 'street': '581 Curtis Meadows'}], 'contact': {'alt_email': 'carlos24@example.org', 'phone': '381.460.3626x49073', 'preferred_contact': 'phone'}, 'email': 'kevin_singleton@hotmail.com', 'name': 'Kevin Singleton'}, 'purchases': [{'currency': 'GBP', 'discount_code': None, 'product_name': 'Casero Vainilla Bimbo ', 'quantity': 4}], 'shipping': {'method': 'pickup', 'preferred_by': '2023-01-21T18:30:23'}}
# ======================================================================================================================================================
# Ejemplo #27 - F1 Score: 0.5
# ------------------------------------------------------------------------------------------
# Texto: Eres un extractor de órdenes de compra. Genera SOLO un JSON válido EXACTAMENTE con los campos requeridos.
# Reglas:
# - Usa null cuando un campo no exista.
# - "buyer" debe existir; si name/email/contact/addresses faltan, déjalos en null.
# - Si addresses está vacío o no existe -> "addresses": null.
# - Si purchases está vacío o no existe -> "purchases": null.
# - shipping es opcional; si falta -> "shipping": null.
# - Asegura que los tipos de datos principales sean correctos (quantity: entero; country uno de US/CA/GB/ES/CO/DE/FR).
#
# Texto:
# ¡Hola! 😊 Espero que estés bien. Quería hacer un pedido parecido al que hice la otra vez, si puedes ayudarme. Estoy interesada en unas arepas de queso con chía, necesito más o menos dos. 🥳 También me gustaría pedir un par de esos ricos ring cakes de naranja, ¿te acordás? Esa mezcla de sabores es simplemente increíble. ¡Ah! Y no te olvides de incluir unas seis leches colanta enteras, son las mejores para el desayuno, ¿no crees? 🥛
#
# Sobre la entrega, preferiría recogerlo. No me viene bien que me lo envíen este fin de semana, así que quizás podamos coordinarlo para el próximo lunes. 🌞 Estoy en Bruneau, en la rue Claudine Albert, por si acaso, el código postal es 90546, en Francia. Pero si no te es conveniente, también puedo pasar por Luckau o Stade, que son en Alemania y tengo esas direcciones listas también.
#
# Si tenés alguna pregunta, podés escribirme a mi correo, que es lori.wood1@hotmail.com, aunque mi teléfono es preferido, me lo puedes pedir si hace falta. Por cierto, ayer llovió por aquí y me quedé en casa, ¡menos mal que tenía algunos snacks! 🍕
#
# Espero tu respuesta pronto. ¡Gracias!
#
# RESPONDE SOLO CON EL JSON VÁLIDO (nada más):
# JSON:
# {"buyer": {"addresses": [{"city": "Bruneau", "country": "FR", "postal_code": "90546", "state": null, "street": "45 rue Claudine Albert"}], "contact": {"alt_email": "lori.wood1@hotmail.com", "phone": null, "preferred_contact": "email"}, "email": null, "name": "Lori Wood"}, "purchases": [{"currency": "EUR", "discount_code": null, "product_name": "Arepas de queso con chía ", "quantity": 2}, {"currency": "EUR", "discount_code": null, "product_name": "Rico ring cake naranja ", "quantity": 6}, {"currency": "EUR", "discount_code": null, "product_name": "Leche colanta entera ", "quantity": 6}], "shipping": {"method": "pickup", "preferred_by": "2023-01-03T12:52:22"}}
# ------------------------------------------------------------------------------------------
# Pred_normalizado: {'buyer': {'addresses': [{'city': 'Bruneau', 'country': 'FR', 'postal_code': '90546', 'state': None, 'street': '45 rue Claudine Albert'}], 'contact': {'alt_email': 'lori.wood1@hotmail.com', 'phone': None, 'preferred_contact': 'email'}, 'email': None, 'name': 'Lori Wood'}, 'purchases': [{'currency': 'EUR', 'discount_code': None, 'product_name': 'Arepas de queso con chía ', 'quantity': 2}, {'currency': 'EUR', 'discount_code': None, 'product_name': 'Rico ring cake naranja ', 'quantity': 6}, {'currency': 'EUR', 'discount_code': None, 'product_name': 'Leche colanta entera ', 'quantity': 6}], 'shipping': {'method': 'pickup', 'preferred_by': '2023-01-03T12:52:22'}}
# ------------------------------------------------------------------------------------------
# True: {'buyer': {'addresses': [{'city': 'Bruneau', 'country': 'FR', 'postal_code': '90546', 'state': None, 'street': '5, rue Claudine Albert'}, {'city': 'Luckau', 'country': 'DE', 'postal_code': '68921', 'state': None, 'street': 'Maike-Boucsein-Gasse 2/7'}, {'city': 'Stade', 'country': 'DE', 'postal_code': '84901', 'state': None, 'street': 'Jana-Fröhlich-Ring 15-11'}], 'contact': {'alt_email': 'meganrivera@example.com', 'phone': None, 'preferred_contact': 'phone'}, 'email': 'lori.wood1@hotmail.com', 'name': 'Lori Wood'}, 'purchases': [{'currency': 'EUR', 'discount_code': None, 'product_name': 'Arepas de queso con semilla de chía don maíz ', 'quantity': 2}, {'currency': 'GBP', 'discount_code': None, 'product_name': 'Ring cake naranja ', 'quantity': 2}, {'currency': None, 'discount_code': None, 'product_name': 'Leche colanta entera litron ', 'quantity': 6}], 'shipping': {'method': 'pickup', 'preferred_by': '2023-01-27T05:54:40'}}
# ======================================================================================================================================================
